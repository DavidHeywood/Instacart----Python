# %% [markdown]
# # Contents
# ## Importing libraries and data (orders_checked.csv, orders_products__prior.csv)
# ## Merging the two datasets
# ## Exporting the merged data as orders_products_combined.pkl

# %% [markdown]
# # Getting set up

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
# Turning project folder into a string
path = r'C:\Users\davau\OneDrive - College of the Sequoias\Career Foundry\Data Immersion\Achievement 4 (Python)\Instacart Basket Analysis'

# %%
# Importing orders_checked.csv
df_ords_checked = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'), index_col = False)

# %%
df_ords_checked.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             1           1   2398795        1    prior             2
# 2             2           2    473747        1    prior             3
# 3             3           3   2254736        1    prior             4
# 4             4           4    431534        1    prior             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                   2                  8                     NaN
# 1                   3                  7                    15.0
# 2                   3                 12                    21.0
# 3                   4                  7                    29.0
# 4                   4                 15                    28.0

# %%
# Importing order_products__prior.csv
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products__prior.csv'), index_col = False)

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# Checking shapes of dfs
df_ords_checked.shape
# Out:
# (3421083, 9)

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
# I want to drop the excess Unnamed column in df_ords_checked.  Here's a test run.
df_ords_checked.drop(columns=['Unnamed: 0.1'])
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 1                 1   2398795        1    prior             2
# 2                 2    473747        1    prior             3
# 3                 3   2254736        1    prior             4
# 4                 4    431534        1    prior             5
# ...             ...       ...      ...      ...           ...
# 3421078     3421078   2266710   206209    prior            10
# 3421079     3421079   1854736   206209    prior            11
# 3421080     3421080    626363   206209    prior            12
# 3421081     3421081   2977660   206209    prior            13
# 3421082     3421082    272231   206209    train            14
#
#          orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                         2                  8                     NaN
# 1                         3                  7                    15.0
# ...

# %%
# Seems to have worked, so let me overwrite df_ords_checked.
df_ords_checked = df_ords_checked.drop(columns=['Unnamed: 0.1'])

# %%
df_ords_checked.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           1   2398795        1    prior             2                   3
# 2           2    473747        1    prior             3                   3
# 3           3   2254736        1    prior             4                   4
# 4           4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_ords_checked.shape
# Out:
# (3421083, 8)

# %% [markdown]
# # Merging df_ords_checked and df_ords_prior

# %%
# Merging...
df_merged_large = df_ords_checked.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           0   2539329        1    prior             1                   2
# 2           0   2539329        1    prior             1                   2
# 3           0   2539329        1    prior             1                   2
# 4           0   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# # Exporting df_merged_large

# %%
# Exporting in pickle format (rather than .csv) for efficiency
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))
