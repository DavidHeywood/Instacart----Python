# %% [markdown]
# # Contents
#
# ## Importing Libraries and Data (orders_products_busy.pkl)
# ## The groupby() Function
# ## Aggregating with agg()
# ## Aggregating with transform()
# ## Deriving 'loyalty_flag' column with loc()

# %% [markdown]
# # Importing Libraries and Dataframes

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
# Turning project folder into a string
path = r'C:\Users\davau\OneDrive - College of the Sequoias\Career Foundry\Data Immersion\Achievement 4 (Python)\Instacart Basket Analysis'

# %%
# Importing the main dataframe that I exported after Task 4.7
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_busy.pkl'))

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
df_ords_prods_merge.tail()
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 32404854   1320836   202557    prior            17                   2
# 32404855     31526   202557    prior            18                   5
# 32404856    758936   203436    prior             1                   2
# 32404857   2745165   203436    prior             2                   3
# 32404858   3093936   205420    prior             1                   4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 32404854                 15                     1.0       43553
# 32404855                 11                     3.0       43553
# 32404856                  7                     NaN       42338
# 32404857                  5                    15.0       42338
# 32404858                 14                     NaN       28818
#
#           add_to_cart_order  reordered                   product_name  \
# 32404854                  2          1            Orange Energy Shots
# ...

# %%
# Creating a subse of the first 1,000,000 rows of df_ords_prods_merge
df = df_ords_prods_merge[:1000000]

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
df.tail()
# Out:
#         order_id  user_id eval_set  order_number  orders_day_of_week  \
# 999995   2836489   164627    prior            14                   0
# 999996   1843600   164632    prior             5                   1
# 999997    733106   164632    prior             9                   2
# 999998   1650124   164632    prior            17                   6
# 999999   3378258   164632    prior            22                   6
#
#         order_hour_of_day  days_since_prior_order  product_id  \
# 999995                 15                     6.0       30489
# 999996                 19                     9.0       30489
# 999997                 22                    10.0       30489
# 999998                 17                    13.0       30489
# 999999                 10                    15.0       30489
#
#         add_to_cart_order  reordered     product_name  aisle_id  \
# 999995                  2          0  Original Hummus        67
# ...

# %%
df.shape
# Out:
# (1000000, 19)

# %% [markdown]
# # The groupby() function

# %%
df.groupby('product_name')

# %% [markdown]
# # Aggregating Data with agg()

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# # Aggregating Data with transform()

# %%
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# ...

# %%
pd.options.display.max_rows = None

# %%
df_ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# ...

# %% [markdown]
# # Deriving Columns with loc()

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
df_ords_prods_merge[['user_id', 'loyalty_flag']].head(60)
# Out:
#     user_id      loyalty_flag
# 0         1      New customer
# 1         1      New customer
# 2         1      New customer
# 3         1      New customer
# 4         1      New customer
# 5         1      New customer
# 6         1      New customer
# 7         1      New customer
# 8         1      New customer
# 9         1      New customer
# 10       15  Regular customer
# 11       15  Regular customer
# 12       15  Regular customer
# 13       15  Regular customer
# 14       15  Regular customer
# 15       19      New customer
# 16       19      New customer
# 17       19      New customer
# 18       21  Regular customer
# 19       31  Regular customer
# 20       31  Regular customer
# 21       43  Regular customer
# 22       43  Regular customer
# 23       52  Regular customer
# 24       52  Regular customer
# 25       52  Regular customer
# 26       52  Regular customer
# 27       52  Regular customer
# 28       52  Regular customer
# 29       52  Regular customer
# ...
