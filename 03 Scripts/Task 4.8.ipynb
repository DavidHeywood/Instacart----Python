# %% [markdown]
# # Contents
#
# ## Importing Libraries and Data (orders_products_busy.pkl)
# ## Aggregated mean of 'order_number' by 'department_id'
# ## Creating a loyalty flag
# ### &emsp; Creating a 'max_order' column
# ### &emsp; Creating the 'loyalty_flag' column
# ## Creating a spending flag
# ### &emsp; Creating an 'avg_price' column
# ### &emsp; Creating the 'spending_flag' column
# ## Creating an order frequency flag
# ### &emsp; Creating a 'median_days_since_prior_order' column
# ### &emsp; Creating the 'order_frequency_flag' column
# ## Exporting data as orders_products_agg.pkl
# ## Appendix: Consistency check on the 'price' column discovered during Exercise 4.9

# %% [markdown]
# # Step 1: Importing Libraries and Dataframes

# %%
# Importing Libraries

import pandas as pd
import numpy as np
import os

# %%
# Turning project folder into a string

path = r'C:\Users\davau\OneDrive - College of the Sequoias\Career Foundry\Data Immersion\Achievement 4 (Python)\Instacart Basket Analysis'

# %%
# Importing the main dataframe that I exported after Task 4.7

df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_busy.pkl'))

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 19)

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# 0          0         Soda        77              7     9.0   both
# 1          1         Soda        77              7     9.0   both
# 2          1         Soda        77              7     9.0   both
# 3          1         Soda        77              7     9.0   both
# 4          1         Soda        77              7     9.0   both
#
#      price_range_loc     busiest_day    busiest_days busiest_period_of_day
# 0  Mid-range product  Regularly busy  Regularly busy        Average orders
# 1  Mid-range product  Regularly busy      Least busy        Average orders
# 2  Mid-range product  Regularly busy      Least busy           Most orders
# 3  Mid-range product      Least busy      Least busy        Average orders
# 4  Mid-range product      Least busy      Least busy           Most orders

# %% [markdown]
# # Step 2

# %%
# Finding the aggregated mean of 'order_number' by 'department_id'

df_ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# # Step 3

# %% [markdown]
# Looking through the output, I notice that department_id=21 (missing) is the one with the largest mean order number; however, as this is not actually a department but rather an indication that there was no department listed with the item, the most popular department is really department_id=10 (bulk).  Meanwhile, department_id=5 (alcohol) is the one with the smallest mean order number (the least popular department).  Moreover, the means are all fairly close, with all but 3 departments having a mean between 15 and 20.
#
# These results differ from those of the subset in a couple of ways.  One, the results for the subset did not include all departments, whereas these results do.  Two, the reported means are different because the subset didn't contain all the data.

# %% [markdown]
# # Step 4: Creating a loyalty flag

# %% [markdown]
# ## Creating a 'max_order' column to use for creating the loyalty flag later

# %%
# Creating the `max_order' column

df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Checking to make sure it was added

df_ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# 0          0         Soda        77              7     9.0   both
# 1          1         Soda        77              7     9.0   both
# 2          1         Soda        77              7     9.0   both
# 3          1         Soda        77              7     9.0   both
# 4          1         Soda        77              7     9.0   both
#
#      price_range_loc     busiest_day    busiest_days busiest_period_of_day  \
# 0  Mid-range product  Regularly busy  Regularly busy        Average orders
# 1  Mid-range product  Regularly busy      Least busy        Average orders
# 2  Mid-range product  Regularly busy      Least busy           Most orders
# 3  Mid-range product      Least busy      Least busy        Average orders
# 4  Mid-range product      Least busy      Least busy           Most orders
#
#    max_order
# 0         10
# 1         10
# 2         10
# 3         10
# 4         10

# %% [markdown]
# ## Creating the 'loyalty_flag' column

# %%
# Customers with over 40 orders labeled 'Loyal customer'

df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
# Customers with between 11 and 40 orders (inclusive) labeled 'Regular customer'

df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
# Customers with 10 or fewer orders labeled 'New customer'

df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Checking the new 'loyalty_flag' column

df_ords_prods_merge.head(20)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# 13   2715276       15    prior            21                   1
# 14    487368       15    prior            22                   1
# 15   2293453       19    prior             2                   5
# 16   1973799       19    prior             5                   6
# 17    532817       19    prior             7                   4
# 18   1573906       21    prior            10                   3
# 19   1593000       31    prior            10                   3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
# 15                 14                     6.0         196                  3
# 16                 12                     8.0         196                 15
# 17                 17                     6.0         196                  1
# 18                 10                     6.0         196                  2
# 19                  8                     7.0         196                 17
#
#     reordered  ... aisle_id  department_id  prices  _merge    price_range_loc  \
# 0           0  ...       77              7     9.0    both  Mid-range product
# 1           1  ...       77              7     9.0    both  Mid-range product
# 2           1  ...       77              7     9.0    both  Mid-range product
# 3           1  ...       77              7     9.0    both  Mid-range product
# 4           1  ...       77              7     9.0    both  Mid-range product
# 5           1  ...       77              7     9.0    both  Mid-range product
# 6           1  ...       77              7     9.0    both  Mid-range product
# 7           1  ...       77              7     9.0    both  Mid-range product
# 8           1  ...       77              7     9.0    both  Mid-range product
# 9           1  ...       77              7     9.0    both  Mid-range product
# 10          0  ...       77              7     9.0    both  Mid-range product
# 11          1  ...       77              7     9.0    both  Mid-range product
# 12          1  ...       77              7     9.0    both  Mid-range product
# 13          1  ...       77              7     9.0    both  Mid-range product
# 14          1  ...       77              7     9.0    both  Mid-range product
# 15          0  ...       77              7     9.0    both  Mid-range product
# 16          1  ...       77              7     9.0    both  Mid-range product
# 17          1  ...       77              7     9.0    both  Mid-range product
# 18          0  ...       77              7     9.0    both  Mid-range product
# 19          0  ...       77              7     9.0    both  Mid-range product
#
#        busiest_day    busiest_days busiest_period_of_day max_order  \
# 0   Regularly busy  Regularly busy        Average orders        10
# 1   Regularly busy      Least busy        Average orders        10
# 2   Regularly busy      Least busy           Most orders        10
# 3       Least busy      Least busy        Average orders        10
# 4       Least busy      Least busy           Most orders        10
# 5   Regularly busy  Regularly busy        Average orders        10
# 6   Regularly busy         Busiest           Most orders        10
# 7   Regularly busy         Busiest           Most orders        10
# 8   Regularly busy         Busiest           Most orders        10
# 9       Least busy      Least busy        Average orders        10
# 10  Regularly busy         Busiest           Most orders        22
# 11  Regularly busy  Regularly busy           Most orders        22
# 12  Regularly busy  Regularly busy           Most orders        22
# 13  Regularly busy         Busiest           Most orders        22
# 14  Regularly busy         Busiest           Most orders        22
# 15  Regularly busy  Regularly busy           Most orders         9
# 16  Regularly busy  Regularly busy           Most orders         9
# 17      Least busy      Least busy        Average orders         9
# 18  Regularly busy      Least busy           Most orders        33
# 19  Regularly busy      Least busy        Average orders        20
#
#         loyalty_flag
# 0       New customer
# 1       New customer
# 2       New customer
# 3       New customer
# 4       New customer
# 5       New customer
# 6       New customer
# 7       New customer
# 8       New customer
# 9       New customer
# 10  Regular customer
# 11  Regular customer
# 12  Regular customer
# 13  Regular customer
# 14  Regular customer
# 15      New customer
# 16      New customer
# 17      New customer
# 18  Regular customer
# 19  Regular customer
#
# [20 rows x 21 columns]

# %%
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# # Step 5

# %%
# Checking basic statistics on the three types of customers flagged above. 

df_ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['min', 'max', 'sum','mean']})
# Out:
#                  prices
#                     min      max          sum       mean
# loyalty_flag
# Loyal customer      1.0  99999.0  106814042.2  10.386336
# New customer        1.0  99999.0   83011787.2  13.294670
# Regular customer    1.0  99999.0  198391693.2  12.495717

# %% [markdown]
# On average, loyal customers choose cheaper products than new and regular customers.  Regular customers contributed most to Instacart revenue, but this is likely due to the fact that there are more of them than loyal customers.

# %% [markdown]
# # Step 6

# %% [markdown]
# ## Creating an 'avg_price' column to use for creating the 'spending' flag later

# %%
# Creating the 'avg_price' column, which displays the mean price of the items purchased by each user

df_ords_prods_merge['avg_price'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Checking the new 'avg_price' column

df_ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# 13   2715276       15    prior            21                   1
# 14    487368       15    prior            22                   1
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
#
#     reordered  ... department_id  prices  _merge    price_range_loc  \
# 0           0  ...             7     9.0    both  Mid-range product
# 1           1  ...             7     9.0    both  Mid-range product
# 2           1  ...             7     9.0    both  Mid-range product
# 3           1  ...             7     9.0    both  Mid-range product
# 4           1  ...             7     9.0    both  Mid-range product
# 5           1  ...             7     9.0    both  Mid-range product
# 6           1  ...             7     9.0    both  Mid-range product
# 7           1  ...             7     9.0    both  Mid-range product
# 8           1  ...             7     9.0    both  Mid-range product
# 9           1  ...             7     9.0    both  Mid-range product
# 10          0  ...             7     9.0    both  Mid-range product
# 11          1  ...             7     9.0    both  Mid-range product
# 12          1  ...             7     9.0    both  Mid-range product
# 13          1  ...             7     9.0    both  Mid-range product
# 14          1  ...             7     9.0    both  Mid-range product
#
#        busiest_day    busiest_days busiest_period_of_day max_order  \
# 0   Regularly busy  Regularly busy        Average orders        10
# 1   Regularly busy      Least busy        Average orders        10
# 2   Regularly busy      Least busy           Most orders        10
# 3       Least busy      Least busy        Average orders        10
# 4       Least busy      Least busy           Most orders        10
# 5   Regularly busy  Regularly busy        Average orders        10
# 6   Regularly busy         Busiest           Most orders        10
# 7   Regularly busy         Busiest           Most orders        10
# 8   Regularly busy         Busiest           Most orders        10
# 9       Least busy      Least busy        Average orders        10
# 10  Regularly busy         Busiest           Most orders        22
# 11  Regularly busy  Regularly busy           Most orders        22
# 12  Regularly busy  Regularly busy           Most orders        22
# 13  Regularly busy         Busiest           Most orders        22
# 14  Regularly busy         Busiest           Most orders        22
#
#         loyalty_flag  avg_price
# 0       New customer   6.367797
# 1       New customer   6.367797
# 2       New customer   6.367797
# 3       New customer   6.367797
# 4       New customer   6.367797
# 5       New customer   6.367797
# 6       New customer   6.367797
# 7       New customer   6.367797
# 8       New customer   6.367797
# 9       New customer   6.367797
# 10  Regular customer   3.980556
# 11  Regular customer   3.980556
# 12  Regular customer   3.980556
# 13  Regular customer   3.980556
# 14  Regular customer   3.980556
#
# [15 rows x 22 columns]

# %% [markdown]
# ## Creating the 'spending_flag' column

# %%
# If avg_price < 10, labeled 'Low spender'

df_ords_prods_merge.loc[df_ords_prods_merge['avg_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
# If avg_price >= 10, labeled 'High spender'

df_ords_prods_merge.loc[df_ords_prods_merge['avg_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
# Checking the new 'spending_flag' column

df_ords_prods_merge.head(20)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# 13   2715276       15    prior            21                   1
# 14    487368       15    prior            22                   1
# 15   2293453       19    prior             2                   5
# 16   1973799       19    prior             5                   6
# 17    532817       19    prior             7                   4
# 18   1573906       21    prior            10                   3
# 19   1593000       31    prior            10                   3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
# 15                 14                     6.0         196                  3
# 16                 12                     8.0         196                 15
# 17                 17                     6.0         196                  1
# 18                 10                     6.0         196                  2
# 19                  8                     7.0         196                 17
#
#     reordered  ... prices  _merge    price_range_loc     busiest_day  \
# 0           0  ...    9.0    both  Mid-range product  Regularly busy
# 1           1  ...    9.0    both  Mid-range product  Regularly busy
# 2           1  ...    9.0    both  Mid-range product  Regularly busy
# 3           1  ...    9.0    both  Mid-range product      Least busy
# 4           1  ...    9.0    both  Mid-range product      Least busy
# 5           1  ...    9.0    both  Mid-range product  Regularly busy
# 6           1  ...    9.0    both  Mid-range product  Regularly busy
# 7           1  ...    9.0    both  Mid-range product  Regularly busy
# 8           1  ...    9.0    both  Mid-range product  Regularly busy
# 9           1  ...    9.0    both  Mid-range product      Least busy
# 10          0  ...    9.0    both  Mid-range product  Regularly busy
# 11          1  ...    9.0    both  Mid-range product  Regularly busy
# 12          1  ...    9.0    both  Mid-range product  Regularly busy
# 13          1  ...    9.0    both  Mid-range product  Regularly busy
# 14          1  ...    9.0    both  Mid-range product  Regularly busy
# 15          0  ...    9.0    both  Mid-range product  Regularly busy
# 16          1  ...    9.0    both  Mid-range product  Regularly busy
# 17          1  ...    9.0    both  Mid-range product      Least busy
# 18          0  ...    9.0    both  Mid-range product  Regularly busy
# 19          0  ...    9.0    both  Mid-range product  Regularly busy
#
#       busiest_days busiest_period_of_day max_order      loyalty_flag  \
# 0   Regularly busy        Average orders        10      New customer
# 1       Least busy        Average orders        10      New customer
# 2       Least busy           Most orders        10      New customer
# 3       Least busy        Average orders        10      New customer
# 4       Least busy           Most orders        10      New customer
# 5   Regularly busy        Average orders        10      New customer
# 6          Busiest           Most orders        10      New customer
# 7          Busiest           Most orders        10      New customer
# 8          Busiest           Most orders        10      New customer
# 9       Least busy        Average orders        10      New customer
# 10         Busiest           Most orders        22  Regular customer
# 11  Regularly busy           Most orders        22  Regular customer
# 12  Regularly busy           Most orders        22  Regular customer
# 13         Busiest           Most orders        22  Regular customer
# 14         Busiest           Most orders        22  Regular customer
# 15  Regularly busy           Most orders         9      New customer
# 16  Regularly busy           Most orders         9      New customer
# 17      Least busy        Average orders         9      New customer
# 18      Least busy           Most orders        33  Regular customer
# 19      Least busy        Average orders        20  Regular customer
#
#    avg_price  spending_flag
# 0   6.367797    Low spender
# 1   6.367797    Low spender
# 2   6.367797    Low spender
# 3   6.367797    Low spender
# 4   6.367797    Low spender
# 5   6.367797    Low spender
# 6   6.367797    Low spender
# 7   6.367797    Low spender
# 8   6.367797    Low spender
# 9   6.367797    Low spender
# 10  3.980556    Low spender
# 11  3.980556    Low spender
# 12  3.980556    Low spender
# 13  3.980556    Low spender
# 14  3.980556    Low spender
# 15  8.372059    Low spender
# 16  8.372059    Low spender
# 17  8.372059    Low spender
# 18  7.012683    Low spender
# 19  8.137793    Low spender
#
# [20 rows x 23 columns]

# %%
# Getting a frequency distribution for 'spending_flag'

df_ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spending_flag, dtype: int64

# %% [markdown]
# # Step 7

# %% [markdown]
# ## Creating a 'median_days_since_prior_order' column to use for creating the 'order frequency' flag later

# %%
# Creating the 'median_days_since_prior_order' column, 
# which displays the median number of days each user takes between orders

df_ords_prods_merge['median_days_since_prior_order'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Checking the new 'median_days_since_prior_order' column

df_ords_prods_merge.head(20)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# 13   2715276       15    prior            21                   1
# 14    487368       15    prior            22                   1
# 15   2293453       19    prior             2                   5
# 16   1973799       19    prior             5                   6
# 17    532817       19    prior             7                   4
# 18   1573906       21    prior            10                   3
# 19   1593000       31    prior            10                   3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
# 15                 14                     6.0         196                  3
# 16                 12                     8.0         196                 15
# 17                 17                     6.0         196                  1
# 18                 10                     6.0         196                  2
# 19                  8                     7.0         196                 17
#
#     reordered  ... _merge    price_range_loc     busiest_day    busiest_days  \
# 0           0  ...   both  Mid-range product  Regularly busy  Regularly busy
# 1           1  ...   both  Mid-range product  Regularly busy      Least busy
# 2           1  ...   both  Mid-range product  Regularly busy      Least busy
# 3           1  ...   both  Mid-range product      Least busy      Least busy
# 4           1  ...   both  Mid-range product      Least busy      Least busy
# 5           1  ...   both  Mid-range product  Regularly busy  Regularly busy
# 6           1  ...   both  Mid-range product  Regularly busy         Busiest
# 7           1  ...   both  Mid-range product  Regularly busy         Busiest
# 8           1  ...   both  Mid-range product  Regularly busy         Busiest
# 9           1  ...   both  Mid-range product      Least busy      Least busy
# 10          0  ...   both  Mid-range product  Regularly busy         Busiest
# 11          1  ...   both  Mid-range product  Regularly busy  Regularly busy
# 12          1  ...   both  Mid-range product  Regularly busy  Regularly busy
# 13          1  ...   both  Mid-range product  Regularly busy         Busiest
# 14          1  ...   both  Mid-range product  Regularly busy         Busiest
# 15          0  ...   both  Mid-range product  Regularly busy  Regularly busy
# 16          1  ...   both  Mid-range product  Regularly busy  Regularly busy
# 17          1  ...   both  Mid-range product      Least busy      Least busy
# 18          0  ...   both  Mid-range product  Regularly busy      Least busy
# 19          0  ...   both  Mid-range product  Regularly busy      Least busy
#
#    busiest_period_of_day max_order      loyalty_flag avg_price spending_flag  \
# 0         Average orders        10      New customer  6.367797   Low spender
# 1         Average orders        10      New customer  6.367797   Low spender
# 2            Most orders        10      New customer  6.367797   Low spender
# 3         Average orders        10      New customer  6.367797   Low spender
# 4            Most orders        10      New customer  6.367797   Low spender
# 5         Average orders        10      New customer  6.367797   Low spender
# 6            Most orders        10      New customer  6.367797   Low spender
# 7            Most orders        10      New customer  6.367797   Low spender
# 8            Most orders        10      New customer  6.367797   Low spender
# 9         Average orders        10      New customer  6.367797   Low spender
# 10           Most orders        22  Regular customer  3.980556   Low spender
# 11           Most orders        22  Regular customer  3.980556   Low spender
# 12           Most orders        22  Regular customer  3.980556   Low spender
# 13           Most orders        22  Regular customer  3.980556   Low spender
# 14           Most orders        22  Regular customer  3.980556   Low spender
# 15           Most orders         9      New customer  8.372059   Low spender
# 16           Most orders         9      New customer  8.372059   Low spender
# 17        Average orders         9      New customer  8.372059   Low spender
# 18           Most orders        33  Regular customer  7.012683   Low spender
# 19        Average orders        20  Regular customer  8.137793   Low spender
#
#     median_days_since_prior_order
# 0                            20.5
# 1                            20.5
# 2                            20.5
# 3                            20.5
# 4                            20.5
# 5                            20.5
# 6                            20.5
# 7                            20.5
# 8                            20.5
# 9                            20.5
# 10                           10.0
# 11                           10.0
# 12                           10.0
# 13                           10.0
# 14                           10.0
# 15                            6.0
# 16                            6.0
# 17                            6.0
# 18                            7.5
# 19                            6.0
#
# [20 rows x 24 columns]

# %% [markdown]
# ## Creating the 'order_frequency_flag' column

# %%
# If the median days since prior order is higher than 20, 
# labeled 'Non-frequent customer'

df_ords_prods_merge.loc[df_ords_prods_merge['median_days_since_prior_order'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
# If the median is between 11 and 20 (inclusive), 
# labeled 'Regular customer'

df_ords_prods_merge.loc[(df_ords_prods_merge['median_days_since_prior_order'] > 10) & (df_ords_prods_merge['median_days_since_prior_order'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
# If the median is <= 10, labeled 'Frequent customer'

df_ords_prods_merge.loc[df_ords_prods_merge['median_days_since_prior_order'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# Checking the new 'order_frequency_flag' column

df_ords_prods_merge.head(20)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# 13   2715276       15    prior            21                   1
# 14    487368       15    prior            22                   1
# 15   2293453       19    prior             2                   5
# 16   1973799       19    prior             5                   6
# 17    532817       19    prior             7                   4
# 18   1573906       21    prior            10                   3
# 19   1593000       31    prior            10                   3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
# 15                 14                     6.0         196                  3
# 16                 12                     8.0         196                 15
# 17                 17                     6.0         196                  1
# 18                 10                     6.0         196                  2
# 19                  8                     7.0         196                 17
#
#     reordered  ...    price_range_loc     busiest_day    busiest_days  \
# 0           0  ...  Mid-range product  Regularly busy  Regularly busy
# 1           1  ...  Mid-range product  Regularly busy      Least busy
# 2           1  ...  Mid-range product  Regularly busy      Least busy
# 3           1  ...  Mid-range product      Least busy      Least busy
# 4           1  ...  Mid-range product      Least busy      Least busy
# 5           1  ...  Mid-range product  Regularly busy  Regularly busy
# 6           1  ...  Mid-range product  Regularly busy         Busiest
# 7           1  ...  Mid-range product  Regularly busy         Busiest
# 8           1  ...  Mid-range product  Regularly busy         Busiest
# 9           1  ...  Mid-range product      Least busy      Least busy
# 10          0  ...  Mid-range product  Regularly busy         Busiest
# 11          1  ...  Mid-range product  Regularly busy  Regularly busy
# 12          1  ...  Mid-range product  Regularly busy  Regularly busy
# 13          1  ...  Mid-range product  Regularly busy         Busiest
# 14          1  ...  Mid-range product  Regularly busy         Busiest
# 15          0  ...  Mid-range product  Regularly busy  Regularly busy
# 16          1  ...  Mid-range product  Regularly busy  Regularly busy
# 17          1  ...  Mid-range product      Least busy      Least busy
# 18          0  ...  Mid-range product  Regularly busy      Least busy
# 19          0  ...  Mid-range product  Regularly busy      Least busy
#
#     busiest_period_of_day max_order      loyalty_flag avg_price spending_flag  \
# 0          Average orders        10      New customer  6.367797   Low spender
# 1          Average orders        10      New customer  6.367797   Low spender
# 2             Most orders        10      New customer  6.367797   Low spender
# 3          Average orders        10      New customer  6.367797   Low spender
# 4             Most orders        10      New customer  6.367797   Low spender
# 5          Average orders        10      New customer  6.367797   Low spender
# 6             Most orders        10      New customer  6.367797   Low spender
# 7             Most orders        10      New customer  6.367797   Low spender
# 8             Most orders        10      New customer  6.367797   Low spender
# 9          Average orders        10      New customer  6.367797   Low spender
# 10            Most orders        22  Regular customer  3.980556   Low spender
# 11            Most orders        22  Regular customer  3.980556   Low spender
# 12            Most orders        22  Regular customer  3.980556   Low spender
# 13            Most orders        22  Regular customer  3.980556   Low spender
# 14            Most orders        22  Regular customer  3.980556   Low spender
# 15            Most orders         9      New customer  8.372059   Low spender
# 16            Most orders         9      New customer  8.372059   Low spender
# 17         Average orders         9      New customer  8.372059   Low spender
# 18            Most orders        33  Regular customer  7.012683   Low spender
# 19         Average orders        20  Regular customer  8.137793   Low spender
#
#    median_days_since_prior_order   order_frequency_flag
# 0                           20.5  Non-frequent customer
# 1                           20.5  Non-frequent customer
# 2                           20.5  Non-frequent customer
# 3                           20.5  Non-frequent customer
# 4                           20.5  Non-frequent customer
# 5                           20.5  Non-frequent customer
# 6                           20.5  Non-frequent customer
# 7                           20.5  Non-frequent customer
# 8                           20.5  Non-frequent customer
# 9                           20.5  Non-frequent customer
# 10                          10.0      Frequent customer
# 11                          10.0      Frequent customer
# 12                          10.0      Frequent customer
# 13                          10.0      Frequent customer
# 14                          10.0      Frequent customer
# 15                           6.0      Frequent customer
# 16                           6.0      Frequent customer
# 17                           6.0      Frequent customer
# 18                           7.5      Frequent customer
# 19                           6.0      Frequent customer
#
# [20 rows x 25 columns]

# %%
# Getting a frequency distribution for 'order_frequency_flag'

df_ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: order_frequency_flag, dtype: int64

# %% [markdown]
# # Step 9

# %%
# Exporting df_ords_prods_merge as orders_products_agg.pkl

df_ords_prods_merge.to_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_agg.pkl'))

# %% [markdown]
# # New discoveries during 4.9

# %% [markdown]
# In 4.9, the high max price was noted while trying to make a histogram of the 'price' column.  It was discovered that there were two categories of items with unreasonably high prices: some cost 14,900 and others cost 99,999.  It was decided to treat those as missing values, so they were replaced with NaNs.  The orders_products_agg.pkl exported above does not reflect this change, as it wasn't made until 4.9.  However, the changes have now been exported under the new file name _______ .  The code below was used to replace these high prices with NaNs.

# %%
# Replacing prices over $100 with NaNs

ords_prods_agg.loc[ords_prods_agg['prices'] >100, 'prices'] = np.nan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 # Replacing prices over $100 with NaNs
# ----> 3 ords_prods_agg.loc[ords_prods_agg['prices'] >100, 'prices'] = np.nan
#
# NameError: name 'ords_prods_agg' is not defined
